# %% [markdown]
# # Tensorflow로 Logistic Regression 직접 구현하기

# %%
from sklearn.datasets import make_classification
import tensorflow as tf
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-3529a4889053> in <module>()
#       1 from sklearn.datasets import make_classification
# ----> 2 import tensorflow as tf
#       3 import numpy as np
#
# ModuleNotFoundError: No module named 'tensorflow'

# %% [markdown]
# ## 가상의 data 생성

# %%
X, y = make_classification(n_features=2, n_redundant=0, n_informative=1, 
                            n_clusters_per_class=1, random_state=50)
plt.scatter(X[y == 0, 0], X[y == 0, 1], marker='o')
plt.scatter(X[y == 1, 0], X[y == 1, 1], marker='x')
plt.show()

# %% [markdown]
# - Quiz : 아래 코드에서 np.vstack을 통해 np.ones(100)을 x에 추가해야하는 이유는 무엇일까요?

# %%
x = np.vstack([np.ones(100), X[:,0], X[:,1]])
x
# Out:
# array([[ 1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
# ...

# %% [markdown]
# ## 모델 구축

# %% [markdown]
# ### Tensor build

# %%
xd = tf.placeholder(tf.float32)
yd = tf.placeholder(tf.float32)

# %% [markdown]
# - Quiz : 초기 weight를 선언해보세요. (hint : 머신러닝의 첫번째 과정은 초기 weight를 임의의 값으로 주는 것이다.)

# %%
w = tf.Variable() # (개수, 시작점, 끝점)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-dbe37db5daf8> in <module>()
# ----> 1 w = tf.Variable() # (개수, 시작점, 끝점)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/variables.py in __call__(cls, *args, **kwargs)
#     143   def __call__(cls, *args, **kwargs):
#     144     if cls is Variable:
# --> 145       return cls._variable_call(*args, **kwargs)
#     146     else:
#     147       return super(VariableMetaclass, cls).__call__(*args, **kwargs)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/variables.py in _variable_call(cls, initial_value, trainable, collections, validate_shape, caching_device, name, variable_def, dtype, expected_shape, import_scope, constraint, use_resource, synchronization, aggregation)
#     139         use_resource=use_resource,
#     140         synchronization=synchronization,
# ...

# %% [markdown]
# - Quiz : hypothesis함수와 cost함수를 완성해보세요.

# %%
z = tf.matmul(w, xd)
hypothesis = 
cost =
# Out:
# cost :  0.53499866
# weight:  [[0.97116697 0.6925095  0.48951778]]
# cost :  0.38093975
# weight:  [[0.70718503 1.1640496  0.37640408]]
# cost :  0.32307488
# weight:  [[0.55011517 1.4557258  0.30239818]]
# cost :  0.29625022
# weight:  [[0.45058408 1.6593162  0.25520864]]
# cost :  0.2818209
# weight:  [[0.384501  1.81287   0.2248779]]
# cost :  0.273205
# weight:  [[0.33933023 1.9346428  0.20538989]]
# cost :  0.2676529
# weight:  [[0.30796337 2.0345674  0.19312693]]
# cost :  0.2638625
# weight:  [[0.28607368 2.118591   0.18582569]]
# cost :  0.26115566
# weight:  [[0.2708793  2.1905432  0.18200889]]
# cost :  0.25915202
# weight:  [[0.26051396 2.2530305  0.18067625]]
# cost :  0.2576253
# weight:  [[0.25368407 2.3079085  0.18112975]]
# cost :  0.25643417
# weight:  [[0.24946904 2.356544   0.1828704 ]]
# cost :  0.25548652
# weight:  [[0.2472003  2.3999736  0.18553446]]
# cost :  0.25472024
# weight:  [[0.24638397 2.4390025  0.1888529 ]]
# cost :  0.25409228
# ...

# %%
learning_rate = tf.Variable(0.1)
optimizer = tf.train.GradientDescentOptimizer(learning_rate)
train = optimizer.minimize(cost)

# %% [markdown]
# ### Tensor run

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

for i in range(2001):
    sess.run(train, feed_dict={xd: x, yd: y})

    if i%20 == 0:
        print('cost : ', sess.run(cost, feed_dict={xd: x, yd: y}), '\nweight: ', sess.run(w))

# %%
print('Result')
print('cost: ', sess.run(cost, feed_dict={xd: x, yd: y}), '\nweight: ', sess.run(w))

# %% [markdown]
# ## Prediction

# %%
x_new = [2, 0]
plt.scatter(X[y == 0, 0], X[y == 0, 1], marker='o')
plt.scatter(X[y == 1, 0], X[y == 1, 1], marker='x')
plt.scatter(x_new[0], x_new[1], marker='^', c='r')
plt.show()

# %%
x_new = np.vstack([np.ones(1), x_new[0], x_new[1]])

# %%
print(sess.run(hypothesis, feed_dict={xd: x_new}))
sess.close()
